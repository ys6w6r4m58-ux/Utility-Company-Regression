# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np
import pandas as pd

pd.options.display.float_format = '{:.2f}'.format

# %%
qSales = pd.read_csv('qSales_2024.csv')

display(qSales)
# Out:
#       gvkey    datadate  fyearq  fqtr  fyr indfmt consol popsrc datafmt  \
# 0      1690  2001-03-31    2001     2    9   INDL      C      D     STD
# 1      1690  2001-06-30    2001     3    9   INDL      C      D     STD
# 2      1690  2001-09-30    2001     4    9   INDL      C      D     STD
# 3      1690  2001-12-31    2002     1    9   INDL      C      D     STD
# 4      1690  2002-03-31    2002     2    9   INDL      C      D     STD
# ..      ...         ...     ...   ...  ...    ...    ...    ...     ...
# 272  102450  2022-12-31    2022     3    3   INDL      C      D     STD
# 273  102450  2023-03-31    2022     4    3   INDL      C      D     STD
# 274  102450  2023-06-30    2023     1    3   INDL      C      D     STD
# 275  102450  2023-09-30    2023     2    3   INDL      C      D     STD
# 276  102450  2023-12-31    2023     3    3   INDL      C      D     STD
#
#        tic             conm curcdq datacqtr datafqtr   saleq costat
# 0     AAPL        APPLE INC    USD   2001Q1   2001Q2 1431.00      A
# 1     AAPL        APPLE INC    USD   2001Q2   2001Q3 1475.00      A
# 2     AAPL        APPLE INC    USD   2001Q3   2001Q4 1450.00      A
# 3     AAPL        APPLE INC    USD   2001Q4   2002Q1 1375.00      A
# 4     AAPL        APPLE INC    USD   2002Q1   2002Q2 1495.00      A
# ..     ...              ...    ...      ...      ...     ...    ...
# 272  NTDOY  NINTENDO CO LTD    USD   2022Q4   2022Q3 5280.78      A
# 273  NTDOY  NINTENDO CO LTD    USD   2023Q1   2022Q4 2226.88      A
# 274  NTDOY  NINTENDO CO LTD    USD   2023Q2   2023Q1 3190.81      A
# 275  NTDOY  NINTENDO CO LTD    USD   2023Q3   2023Q2 2140.04      A
# 276  NTDOY  NINTENDO CO LTD    USD   2023Q4   2023Q3 4564.33      A
#
# [277 rows x 16 columns]

# %%
#to do time series forecasting
# Step 0 is always to visualize the data to identify any patterns
# step 1 is to introduce time as one of our components to the model
# step 2 introduce any dummy variables you might find
# step 3 is to do multiple regression modelling

#our focus is to prepare a time series model for apple

# %%
#change date to datetime type

qSales['datadate'] = pd.to_datetime(qSales['datadate'])

# %%
apple_sales = qSales.loc[qSales['tic']=='AAPL']

display(apple_sales)
# Out:
#     gvkey   datadate  fyearq  fqtr  fyr indfmt consol popsrc datafmt   tic  \
# 0    1690 2001-03-31    2001     2    9   INDL      C      D     STD  AAPL
# 1    1690 2001-06-30    2001     3    9   INDL      C      D     STD  AAPL
# 2    1690 2001-09-30    2001     4    9   INDL      C      D     STD  AAPL
# 3    1690 2001-12-31    2002     1    9   INDL      C      D     STD  AAPL
# 4    1690 2002-03-31    2002     2    9   INDL      C      D     STD  AAPL
# ..    ...        ...     ...   ...  ...    ...    ...    ...     ...   ...
# 87   1690 2022-12-31    2023     1    9   INDL      C      D     STD  AAPL
# 88   1690 2023-03-31    2023     2    9   INDL      C      D     STD  AAPL
# 89   1690 2023-06-30    2023     3    9   INDL      C      D     STD  AAPL
# 90   1690 2023-09-30    2023     4    9   INDL      C      D     STD  AAPL
# 91   1690 2023-12-31    2024     1    9   INDL      C      D     STD  AAPL
#
#          conm curcdq datacqtr datafqtr     saleq costat
# 0   APPLE INC    USD   2001Q1   2001Q2   1431.00      A
# 1   APPLE INC    USD   2001Q2   2001Q3   1475.00      A
# 2   APPLE INC    USD   2001Q3   2001Q4   1450.00      A
# 3   APPLE INC    USD   2001Q4   2002Q1   1375.00      A
# 4   APPLE INC    USD   2002Q1   2002Q2   1495.00      A
# ..        ...    ...      ...      ...       ...    ...
# 87  APPLE INC    USD   2022Q4   2023Q1 117154.00      A
# 88  APPLE INC    USD   2023Q1   2023Q2  94836.00      A
# 89  APPLE INC    USD   2023Q2   2023Q3  81797.00      A
# 90  APPLE INC    USD   2023Q3   2023Q4  89498.00      A
# 91  APPLE INC    USD   2023Q4   2024Q1 119575.00      A
#
# [92 rows x 16 columns]

# %%
plt.figure(figsize=(10,6))

plt.title('apple revenue')

plt.xlabel('date')
plt.ylabel('revenue')

plt.plot(apple_sales['datadate'],apple_sales['saleq'],marker='o')

# %%
#to introduce the time component of time series regession forecasting
# all we have to do is add a new column - call it time - and measure incrementally increasing time periods (1, 2, 3, ...)

#base requirement is that each row represents an equal block of time
 # (each row is a day or a quarter, etc.)

apple_sales['time'] = range(1, len(apple_sales) + 1)
#be sure to add the + 1

display(apple_sales)
# Out:
# /tmp/ipykernel_2891/1306342911.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apple_sales['time'] = range(1, len(apple_sales) + 1)
#     gvkey   datadate  fyearq  fqtr  fyr indfmt consol popsrc datafmt   tic  \
# 0    1690 2001-03-31    2001     2    9   INDL      C      D     STD  AAPL
# 1    1690 2001-06-30    2001     3    9   INDL      C      D     STD  AAPL
# 2    1690 2001-09-30    2001     4    9   INDL      C      D     STD  AAPL
# 3    1690 2001-12-31    2002     1    9   INDL      C      D     STD  AAPL
# 4    1690 2002-03-31    2002     2    9   INDL      C      D     STD  AAPL
# ..    ...        ...     ...   ...  ...    ...    ...    ...     ...   ...
# 87   1690 2022-12-31    2023     1    9   INDL      C      D     STD  AAPL
# 88   1690 2023-03-31    2023     2    9   INDL      C      D     STD  AAPL
# 89   1690 2023-06-30    2023     3    9   INDL      C      D     STD  AAPL
# 90   1690 2023-09-30    2023     4    9   INDL      C      D     STD  AAPL
# 91   1690 2023-12-31    2024     1    9   INDL      C      D     STD  AAPL
#
#          conm curcdq datacqtr datafqtr     saleq costat  time
# 0   APPLE INC    USD   2001Q1   2001Q2   1431.00      A     1
# 1   APPLE INC    USD   2001Q2   2001Q3   1475.00      A     2
# 2   APPLE INC    USD   2001Q3   2001Q4   1450.00      A     3
# 3   APPLE INC    USD   2001Q4   2002Q1   1375.00      A     4
# 4   APPLE INC    USD   2002Q1   2002Q2   1495.00      A     5
# ..        ...    ...      ...      ...       ...    ...   ...
# 87  APPLE INC    USD   2022Q4   2023Q1 117154.00      A    88
# 88  APPLE INC    USD   2023Q1   2023Q2  94836.00      A    89
# 89  APPLE INC    USD   2023Q2   2023Q3  81797.00      A    90
# 90  APPLE INC    USD   2023Q3   2023Q4  89498.00      A    91
# 91  APPLE INC    USD   2023Q4   2024Q1 119575.00      A    92
#
# [92 rows x 17 columns]

# %%
# this is how to take 75% and 25% of the dataset

dt4training = apple_sales[:int(0.75 * len(apple_sales))] #takes the first 75% of rows
dt4testing = apple_sales[int(0.75 * len(apple_sales)):] #takes the last 25% of rows

# %%
y = dt4training.loc[:,'saleq']
x = dt4training.loc[:,'time']

x = sm.add_constant(x)

model1 = sm.OLS(y,x).fit()

model1.params
# Out:
# const   -13536.82
# time      1077.61
# dtype: float64

# %% [markdown]
# #apple revenue = -13,536 + 1077.61 * time

# %%
# how to forecast a time series model
# time series is much less precise than regression normally

# %% [markdown]
# #during time series forecasting its best to provide a range
# # luckily python can take care of that for us

# %%
# to get a range of values we do the following
#create new dataframe with prediction results
# get summary frame with a confidence level

model1_prediction_results = model1.get_prediction(x)
prediction_intervals = model1_prediction_results.summary_frame(alpha=0.2) # 80% confidence interval

display(prediction_intervals)
# Out:
#         mean  mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0  -12459.21  2405.04      -15572.09       -9346.34     -25894.35
# 1  -11381.61  2352.57      -14426.58       -8336.64     -24801.17
# 2  -10304.00  2300.54      -13281.62       -7326.39     -23708.44
# 3   -9226.40  2248.95      -12137.24       -6315.55     -22616.16
# 4   -8148.79  2197.84      -10993.50       -5304.09     -21524.33
# ..       ...      ...            ...            ...           ...
# 64  56507.55  2197.84       53662.84       59352.25      43132.00
# 65  57585.15  2248.95       54674.30       60496.00      44195.38
# 66  58662.76  2300.54       55685.14       61640.37      45258.32
# 67  59740.36  2352.57       56695.39       62785.34      46320.80
# 68  60817.97  2405.04       57705.09       63930.84      47382.83
#
#     obs_ci_upper
# 0         975.92
# 1        2037.95
# 2        3100.44
# 3        4163.37
# 4        5226.75
# ..           ...
# 64      69883.09
# 65      70974.92
# 66      72067.20
# 67      73159.93
# 68      74253.10
#
# [69 rows x 6 columns]

# %%
# option 1 for our dummy variable is to check for fqtr == 1
# option 2 for our dummy variable is to list out the dates into a list
# release_dates = ['2011-12-31', '2012-12-31']

apple_sales['iphone_dv'] = np.where(apple_sales['fqtr']==1,1,0)
apple_sales['iphone_interaction'] = apple_sales['time'] * apple_sales['iphone_dv']

display(apple_sales)
# Out:
# /tmp/ipykernel_2891/2790963507.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apple_sales['iphone_dv'] = np.where(apple_sales['fqtr']==1,1,0)
# /tmp/ipykernel_2891/2790963507.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apple_sales['iphone_interaction'] = apple_sales['time'] * apple_sales['iphone_dv']
#     gvkey   datadate  fyearq  fqtr  fyr indfmt consol popsrc datafmt   tic  \
# 0    1690 2001-03-31    2001     2    9   INDL      C      D     STD  AAPL
# 1    1690 2001-06-30    2001     3    9   INDL      C      D     STD  AAPL
# 2    1690 2001-09-30    2001     4    9   INDL      C      D     STD  AAPL
# 3    1690 2001-12-31    2002     1    9   INDL      C      D     STD  AAPL
# 4    1690 2002-03-31    2002     2    9   INDL      C      D     STD  AAPL
# ..    ...        ...     ...   ...  ...    ...    ...    ...     ...   ...
# 87   1690 2022-12-31    2023     1    9   INDL      C      D     STD  AAPL
# 88   1690 2023-03-31    2023     2    9   INDL      C      D     STD  AAPL
# 89   1690 2023-06-30    2023     3    9   INDL      C      D     STD  AAPL
# 90   1690 2023-09-30    2023     4    9   INDL      C      D     STD  AAPL
# 91   1690 2023-12-31    2024     1    9   INDL      C      D     STD  AAPL
#
#          conm curcdq datacqtr datafqtr     saleq costat  time  iphone_dv  \
# 0   APPLE INC    USD   2001Q1   2001Q2   1431.00      A     1          0
# 1   APPLE INC    USD   2001Q2   2001Q3   1475.00      A     2          0
# 2   APPLE INC    USD   2001Q3   2001Q4   1450.00      A     3          0
# 3   APPLE INC    USD   2001Q4   2002Q1   1375.00      A     4          1
# 4   APPLE INC    USD   2002Q1   2002Q2   1495.00      A     5          0
# ..        ...    ...      ...      ...       ...    ...   ...        ...
# 87  APPLE INC    USD   2022Q4   2023Q1 117154.00      A    88          1
# 88  APPLE INC    USD   2023Q1   2023Q2  94836.00      A    89          0
# 89  APPLE INC    USD   2023Q2   2023Q3  81797.00      A    90          0
# 90  APPLE INC    USD   2023Q3   2023Q4  89498.00      A    91          0
# 91  APPLE INC    USD   2023Q4   2024Q1 119575.00      A    92          1
#
#     iphone_interaction
# 0                    0
# 1                    0
# 2                    0
# 3                    4
# 4                    0
# ..                 ...
# 87                  88
# 88                   0
# 89                   0
# 90                   0
# 91                  92
#
# [92 rows x 19 columns]

# %%
# this is how to take 75% and 25% of the dataset

dt4training = apple_sales[:int(0.75 * len(apple_sales))] #takes the first 75% of rows
dt4testing = apple_sales[int(0.75 * len(apple_sales)):] #takes the last 25% of rows

# %%
x = dt4training.loc[:,['time','iphone_dv','iphone_interaction']]
x = sm.add_constant(x)

y = dt4training.loc[:,'saleq']

model_dummy = sm.OLS(y,x).fit()

model_dummy.params
# Out:
# const                -11044.75
# time                    933.21
# iphone_dv            -10422.13
# iphone_interaction      578.33
# dtype: float64

# %% [markdown]
# apple's revenue = -11,044 + 933 * time + -10422 * iphone_dv + 578*(time * iphone_dv)

# %%
# to forecast values
#first prepare the testing independent variables (time, dummy, interaction)
# then use the get_prediction function to forecast the values into the testing set

x_test = dt4testing.loc[:,['time','iphone_dv','iphone_interaction']]
x_test = sm.add_constant(x_test)

# %%
model_dummy.get_prediction(x_test).summary_frame(alpha=0.2)
model_dummy.get_prediction(x_test).summary_frame(alpha=0.1)
# Out:
#         mean  mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 69  54280.00  2160.94       51482.20       57077.80      43950.72
# 70  55213.21  2207.41       52355.25       58071.17      44867.47
# 71  87363.94  3895.97       82319.78       92408.10      76214.50
# 72  57079.63  2301.23       54100.21       60059.06      46699.68
# 73  58012.84  2348.54       54972.16       61053.52      47615.14
# 74  58946.05  2396.10       55843.80       62048.31      48530.18
# 75  93410.10  4233.82       87928.53       98891.67      82056.07
# 76  60812.48  2491.90       57586.18       64038.77      50358.99
# 77  61745.69  2540.12       58456.96       65034.42      51272.76
# 78  62678.90  2588.54       59327.48       66030.31      52186.12
# 79  99456.25  4578.31       93528.66      105383.85      87880.30
# 80  64545.32  2685.92       61067.82       68022.81      54011.59
# 81  65478.53  2734.87       61937.67       69019.39      54923.71
# 82  66411.74  2783.97       62807.30       70016.18      55835.43
# 83 105502.41  4928.06       99122.00      111882.83      93688.18
# 84  68278.16  2882.61       64546.01       72010.31      57657.65
# 85  69211.37  2932.13       65415.10       73007.64      58568.15
# 86  70144.58  2981.79       66284.03       74005.14      59478.27
# 87 111548.57  5282.02      104709.88      118387.26      99480.67
# 88  72011.00  3081.45       68021.41       76000.59      61297.31
# 89  72944.21  3131.45       68889.89       76998.54      62206.25
# 90  73877.43  3181.55       69758.23       77996.62      63114.80
# 91 117594.73  5639.39      110293.33      124896.12     105258.73
#
#     obs_ci_upper
# 69      64609.28
# 70      65558.95
# 71      98513.38
# 72      67459.58
# 73      68410.54
# 74      69361.93
# 75     104764.13
# 76      71265.96
# 77      72218.61
# 78      73171.68
# 79     111032.21
# 80      75079.05
# 81      76033.35
# 82      76988.05
# 83     117316.65
# 84      78898.68
# 85      79854.59
# 86      80810.90
# 87     123616.46
# 88      82724.70
# 89      83682.18
# 90      84640.05
# 91     129930.72
